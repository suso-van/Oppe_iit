# %% [markdown]
# <a href="https://colab.research.google.com/github/suso-van/Oppe_iit/blob/main/Foundation-Python/Oppe-two-2024/Sep-Set-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2025 SEP OPPE- SET ONE
#
# SECTION ONE PROBLEM - 1

# %%
def is_even_two_digit_number(num):
    """
    Determines whether a given number is an even two-digit number.

    Args:
        num (int): The number to check.

    Returns:
        bool: True if `num` is an even two-digit number, False otherwise.

    Examples:
        >>> is_even_two_digit_number(42)
        True
        >>> is_even_two_digit_number(99)
        False
        >>> is_even_two_digit_number(-48)
        True
        >>> is_even_two_digit_number(5)
        False
    """

    return num % 2 == 0 and 10 <= abs(num) < 100


# Test cases to demonstrate function output
print(f"is_even_two_digit_number(42): {is_even_two_digit_number(42)}")
print(f"is_even_two_digit_number(99): {is_even_two_digit_number(99)}")
print(f"is_even_two_digit_number(-48): {is_even_two_digit_number(-48)}")
print(f"is_even_two_digit_number(5): {is_even_two_digit_number(5)}")
print(f"is_even_two_digit_number(100): {is_even_two_digit_number(100)}")
print(f"is_even_two_digit_number(-10): {is_even_two_digit_number(-10)}")
# Out:
# is_even_two_digit_number(42): True
# is_even_two_digit_number(99): False
# is_even_two_digit_number(-48): True
# is_even_two_digit_number(5): False
# is_even_two_digit_number(100): False
# is_even_two_digit_number(-10): True

# %% [markdown]
# SECTION ONE PROBLEM - 2

# %%
def is_dot_com_or_dot_in(domain):
    """
    Checks whether a given domain ends with '.com' or '.in'.

    Args:
        domain (str): The domain name to check.

    Returns:
        bool: True if the domain ends with '.com' or '.in', False otherwise.

    Examples:
        >>> is_dot_com_or_dot_in('example.com')
        True
        >>> is_dot_com_or_dot_in('example.in')
        True
        >>> is_dot_com_or_dot_in('example.org')
        False
        >>> is_dot_com_or_dot_in('mywebsitein')
        False
    """

    return domain[-4:] == '.com' or domain[-3:] == '.in'

# Test cases to demonstrate function output
print(f"'example.com' -> {is_dot_com_or_dot_in('example.com')}")
print(f"'example.in'  -> {is_dot_com_or_dot_in('example.in')}")
print(f"'example.org' -> {is_dot_com_or_dot_in('example.org')}")
print(f"'mywebsitein' -> {is_dot_com_or_dot_in('mywebsitein')}")
# Out:
# 'example.com' -> True
# 'example.in'  -> True
# 'example.org' -> False
# 'mywebsitein' -> False

# %% [markdown]
# SECTION ONE PROBLEM - 3

# %%
def is_present_in_opposite_halves(elem, l1: list, l2: list):
    """
    Determines whether an element is present in the first half of one list
    and the second half of the other list, or vice versa.

    Args:
        elem (Any): The element to check for.
        l1 (list): The first list to search.
        l2 (list): The second list to search.

    Returns:
        bool: True if `elem` is present in opposite halves of `l1` and `l2`,
        False otherwise.
    """


    m1 = len(l1) // 2
    m2 = len(l2) // 2
    return (
        (elem in l1[:m1] and elem in l2[m2:])
        or (elem in l1[m1:] and elem in l2[:m2])
    )

# Test cases to demonstrate the function
list_a = [1, 2, 3, 4]
list_b = [5, 6, 7, 1]
print(f"Is 1 in opposite halves of {list_a} and {list_b}?")
print(is_present_in_opposite_halves(1, list_a, list_b))

list_c = [1, 2, 3, 4]
list_d = [1, 6, 7, 8]
print(f"\nIs 1 in opposite halves of {list_c} and {list_d}?")
print(is_present_in_opposite_halves(1, list_c, list_d))
# Out:
# Is 1 in opposite halves of [1, 2, 3, 4] and [5, 6, 7, 1]?
# True
#
# Is 1 in opposite halves of [1, 2, 3, 4] and [1, 6, 7, 8]?
# False

# %% [markdown]
# SECTION TWO PROBLEM - 1

# %%
def count_odd_three_digit_nums(nums):


    # count = 0
    # for num in nums:
    #     if num is not None and num%2 and len(str(abs(num)))==3:
    #         count += 1
    # return count
    return sum(
       1
       for num in nums
       if num is not None  and num%2 and len(str(abs(num)))==3
    )

# Test cases to show output
test_list = [101, 202, 303, 44, 505, None, 1001, -123]
result = count_odd_three_digit_nums(test_list)
print(f"Input list: {test_list}")
print(f"Count of odd three-digit numbers: {result}")
# Out:
# Input list: [101, 202, 303, 44, 505, None, 1001, -123]
# Count of odd three-digit numbers: 4

# %% [markdown]
# SECTION TWO PROBLEM - 2

# %%
# Mocking input for demonstration purposes
import io
import sys

sample_input = "4\nMahatma Karamchand Gandhi\nJawaharlal Nehru\nSubhash Chandra Bose\nSardar Vallabhbhai Patel"
sys.stdin = io.StringIO(sample_input)

# Read the number of names
line1 = sys.stdin.readline()
if line1:
    n = int(line1.strip())
    names = []

    # Process each name
    for _ in range(n):
        name = sys.stdin.readline().strip()
        if not name: break
        parts = name.split()
        # Create the abbreviated name
        short_name = f'{". ".join(map(lambda x: x[0], parts[:-1]))}. {parts[-1]}'
        names.append(short_name)

    # Sort and print the results
    for name in sorted(names):
        print(name)
# Out:
# J. Nehru
# M. K. Gandhi
# S. C. Bose
# S. V. Patel

# %% [markdown]
# SECTION THREE PROBLEM - 1

# %%
def item_amount(item):
  return item['price'] * item['quantity']

def total_bill_amount(grocery_list:list)->float:
  total_amount = 0
  for item in grocery_list:
      total_amount += item_amount(item)
  return total_amount

def max_quantity_item(grocery_list:list)->str:
  return max(grocery_list, key=lambda x: x['quantity'])['name']

def sort_by_total_amount(grocery_list:list)->list:
  sorted_items = sorted(
      grocery_list,
      key = lambda x: (-item_amount(x), x['name'])
  )
  return sorted_items


def process_grocery_list(grocery_list:list, request:str):
    """Process the grocery list as per the request.

    Args:
        grocery_list (list[dict]) - A list of dictionary with the keys
            "name", "quantity" and "price", where "price" is the amount of
            one unit of the item.
        request: (str) - A string containing one of the following request.
            - 'total_bill_amount'
            - 'max_quantity_item'
            - 'sort_by_total_amount'

    Returns:
        The output corresponding to the request.
    """


    if request == 'total_bill_amount':
       return total_bill_amount(grocery_list)
    elif request == 'max_quantity_item':
       return max_quantity_item(grocery_list)
    elif request == 'sort_by_total_amount':
       return sort_by_total_amount(grocery_list)
    else:
       return None

# Test data
grocery_data = [
    {'name': 'Apple', 'quantity': 10, 'price': 20},
    {'name': 'Bread', 'quantity': 2, 'price': 50},
    {'name': 'Milk', 'quantity': 5, 'price': 40}
]

print(f"Total Bill Amount: {process_grocery_list(grocery_data, 'total_bill_amount')}")
print(f"Max Quantity Item: {process_grocery_list(grocery_data, 'max_quantity_item')}")
print(f"Sorted by Total Amount: {process_grocery_list(grocery_data, 'sort_by_total_amount')}")
# Out:
# Total Bill Amount: 500
# Max Quantity Item: Apple
# Sorted by Total Amount: [{'name': 'Apple', 'quantity': 10, 'price': 20}, {'name': 'Milk', 'quantity': 5, 'price': 40}, {'name': 'Bread', 'quantity': 2, 'price': 50}]

# %% [markdown]
# SECTION THREE PROBLEM - 2

# %%
import io
import sys
import tempfile

# Mocking input for demonstration
sample_input = "hello world"
sys.stdin = io.StringIO(sample_input)

# This writes the stdin to the input file
_ , filename = tempfile.mkstemp(prefix="case")
with open(filename, 'w') as f:
  f.write(sys.stdin.read())

# Processing the file logic
with open(filename) as f:
    vowel_count = 0
    for line in f:
        for char in line:
            if char.lower() in 'aeiou':
                if vowel_count % 2 == 0:
                    print("ub", end="")
                else:
                    print("dub", end="")
                vowel_count += 1
            print(char, end="")
print() # New line for clarity
# Out:
# hubelldubo wuborld
